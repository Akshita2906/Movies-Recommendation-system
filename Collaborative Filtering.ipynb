# %%
import pandas as pd

# %%
Movie_df=pd.read_csv('Dataset/movies.dat', sep='\t', skiprows=0, encoding='latin-1')
#print(Movie_df)
list(Movie_df)
# Out:
# ['id',
#  'title',
#  'imdbID',
#  'spanishTitle',
#  'imdbPictureURL',
#  'year',
#  'rtID',
#  'rtAllCriticsRating',
#  'rtAllCriticsNumReviews',
#  'rtAllCriticsNumFresh',
#  'rtAllCriticsNumRotten',
#  'rtAllCriticsScore',
#  'rtTopCriticsRating',
#  'rtTopCriticsNumReviews',
#  'rtTopCriticsNumFresh',
#  'rtTopCriticsNumRotten',
#  'rtTopCriticsScore',
#  'rtAudienceRating',
#  'rtAudienceNumRatings',
#  'rtAudienceScore',
#  'rtPictureURL']

# %%
UserRatedMovie_df=pd.read_csv('Dataset/user_ratedmovies.dat', sep='\t', skiprows=0, encoding='latin-1')
#print(UserRatedMovie_df)
list(UserRatedMovie_df)
# Out:
# ['userID',
#  'movieID',
#  'rating',
#  'date_day',
#  'date_month',
#  'date_year',
#  'date_hour',
#  'date_minute',
#  'date_second']

# %%
UserRatedMovieTS_df=pd.read_csv('Dataset/user_ratedmovies-timestamps.dat', sep='\t', skiprows=0, encoding='latin-1')
#print(UserRatedMovieTS_df)
list(UserRatedMovieTS_df)
# Out:
# ['userID', 'movieID', 'rating', 'timestamp']

# %%
UserTaggedMovie_df=pd.read_csv('Dataset/user_taggedmovies.dat', sep='\t', skiprows=0, encoding='latin-1')
#print(UserTaggedMovie_df)
list(UserTaggedMovie_df)
# Out:
# ['userID',
#  'movieID',
#  'tagID',
#  'date_day',
#  'date_month',
#  'date_year',
#  'date_hour',
#  'date_minute',
#  'date_second']

# %%
UserTaggedMovieTS_df=pd.read_csv('Dataset/user_taggedmovies-timestamps.dat', sep='\t', skiprows=0, encoding='latin-1')
#print(UserTaggedMovieTS_df)
list(UserTaggedMovieTS_df)
# Out:
# ['userID', 'movieID', 'tagID', 'timestamp']

# %%
MovieTags_df=pd.read_csv('Dataset/movie_tags.dat', sep='\t', skiprows=0, encoding='latin-1')
#print(MovieTags_df)
list(MovieTags_df)
# Out:
# ['movieID', 'tagID', 'tagWeight']

# %%
MovieLocations_df=pd.read_csv('Dataset/movie_locations.dat', sep='\t', skiprows=0, encoding='latin-1')
#print(MovieLocations_df)
list(MovieLocations_df)
# Out:
# ['movieID', 'location1', 'location2', 'location3', 'location4']

# %%
MovieGenres_df=pd.read_csv('Dataset/movie_genres.dat', sep='\t', skiprows=0, encoding='latin-1')
#print(MovieGenres_df)
list(MovieGenres_df)
# Out:
# ['movieID', 'genre']

# %%
MovieDirectors_df=pd.read_csv('Dataset/movie_directors.dat', sep='\t', skiprows=0, encoding='latin-1')
#print(MovieDirectors_df)
list(MovieDirectors_df)
# Out:
# ['movieID', 'directorID', 'directorName']

# %%
MovieCountries_df=pd.read_csv('Dataset/movie_countries.dat', sep='\t', skiprows=0, encoding='latin-1')
#print(MovieCountries_df)
list(MovieCountries_df)
# Out:
# ['movieID', 'country']

# %%
MovieActors_df=pd.read_csv('Dataset/movie_actors.dat', sep='\t', skiprows=0, encoding='latin-1')
#print(MovieActors_df)
list(MovieActors_df)
# Out:
# ['movieID', 'actorID', 'actorName', 'ranking']

# %%
Tags_df=pd.read_csv('Dataset/tags.dat', sep='\t', skiprows=0, encoding='latin-1')
#print(Tags_df)
list(Tags_df)
# Out:
# ['id', 'value']

# %%
UserRatedMovie_df.loc[UserRatedMovie_df['date_year'] == 2009]
# Out:
#         userID  movieID  rating  date_day  date_month  date_year  date_hour  \
# 1210       190    64497     3.0         3           1       2009         14
# 4928       636      586     3.5         2           1       2009         10
# 5093       636     4034     3.0         2           1       2009          9
# 5119       636     4979     3.0         2           1       2009          9
# 5255       636    52694     3.0         2           1       2009          9
# 5256       636    53322     3.5         2           1       2009          9
# 5266       636    59313     2.5         2           1       2009         10
# 5268       636    59421     2.5         2           1       2009          9
# 9951      1224    26649     4.5         2           1       2009          4
# 10038     1224    52281     2.5         3           1       2009          5
# 10045     1224    53519     2.0         3           1       2009          5
# ...
